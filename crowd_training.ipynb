# %%
# !pip install "ultralytics<=8.3.40"
# Out:
# ...
#      -------------------------------------- 898.5/898.5 kB 7.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 12.9/12.9 MB 4.8 MB/s eta 0:00:00
# ...
#   Using cached matplotlib-3.10.0-cp311-cp311-win_amd64.whl (8.0 MB)
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# ...
#   Using cached pillow-11.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
# ...
#   Using cached scipy-1.15.1-cp311-cp311-win_amd64.whl (43.9 MB)
# ...
#   Using cached torch-2.5.1-cp311-cp311-win_amd64.whl (203.1 MB)
# ...
#   Using cached torchvision-0.20.1-cp311-cp311-win_amd64.whl (1.6 MB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# ...
#   Using cached contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
# ...

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv8 model
model = YOLO('yolov8n.pt')  # Use a lightweight YOLO model (you can choose 'yolov8m' or 'yolov8l' for higher accuracy)

# Train the model on your datasetimport camtest
model.train(data=r"C:\Users\Kaushik\code_JN\crowd_dataset\data.yaml", epochs=50, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.68 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40  Python-3.11.0 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i9-12900K)
# ...

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
import torch
print(torch.cuda.is_available())  # Should return True
print(torch.cuda.get_device_name(0))  # Should return your GPU name, e.g., NVIDIA 4060
# Out:
# False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import torch
#       2 print(torch.cuda.is_available())  # Should return True
# ----> 3 print(torch.cuda.get_device_name(0))  # Should return your GPU name, e.g., NVIDIA 4060
#
# File ~\code_JN\crowd_env\Lib\site-packages\torch\cuda\__init__.py:493, in get_device_name(device)
#     481 def get_device_name(device: Optional[_device_t] = None) -> str:
#     482     r"""Get the name of a device.
#     483
#     484     Args:
#    (...)
#     491         str: the name of the device
#     492     """
# --> 493     return get_device_properties(device).name
#
# File ~\code_JN\crowd_env\Lib\site-packages\torch\cuda\__init__.py:523, in get_device_properties(device)
#     513 def get_device_properties(device: _device_t) -> _CudaDeviceProperties:
#     514     r"""Get the properties of a device.
#     515
# ...

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ---------------------------------------- 0.0/913.6 kB ? eta -:--:--
#    ---------------------------------------- 913.6/913.6 kB 8.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    -- ------------------------------------- 2.9/39.5 MB 21.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 4.7/39.5 MB 10.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.5/39.5 MB 8.6 MB/s eta 0:00:04
#    ------ --------------------------------- 6.6/39.5 MB 7.9 MB/s eta 0:00:05
#    ------- -------------------------------- 7.9/39.5 MB 7.5 MB/s eta 0:00:05
#    -------- ------------------------------- 8.7/39.5 MB 7.0 MB/s eta 0:00:05
#    --------- ------------------------------ 9.7/39.5 MB 6.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.0/39.5 MB 6.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.5/39.5 MB 5.7 MB/s eta 0:00:06
# ...

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())  # Should print True
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# CUDA Available: False

# %%
# !crowd_env\Scripts\deactivate  # On Windows

# %%
# !where python
# Out:
# C:\Users\Kaushik\anaconda3\python.exe
# C:\Users\Kaushik\AppData\Local\Programs\Python\Python311\python.exe
# C:\Users\Kaushik\AppData\Local\Programs\Python\Python313\python.exe
# C:\Users\Kaushik\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.5.1+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: C:\Users\Kaushik\anaconda3\Lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, setuptools, sympy, typing-extensions
# Required-by: torchaudio, torchvision, ultralytics, ultralytics-thop

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Wed_Jan_15_19:38:46_Pacific_Standard_Time_2025
# Cuda compilation tools, release 12.8, V12.8.61
# Build cuda_12.8.r12.8/compiler.35404655_0
